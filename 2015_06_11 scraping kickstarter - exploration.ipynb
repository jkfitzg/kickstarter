# %%
import requests
from bs4 import BeautifulSoup
import pprint

# %%
#rewards_link = 'https://www.kickstarter.com/projects/1284004843/the-caretaker-by-harold-pinter/rewards'
page_link = 'https://www.kickstarter.com/projects/1284004843/the-caretaker-by-harold-pinter/description'

# %%
p = requests.get(page_link)

# %%
type(p)
# Out:
# requests.models.Response

# %%
print p
# Out:
# <Response [200]>

# %%
p.headers['content-type']
# Out:
# 'text/html; charset=utf-8'

# %%
p.text
# Out:
# u'<div class="NS_projects__description_section">\n<div class="py6 bg-white">\n<div class="container-flex px2">\n<div class="row">\n<div class="col col-8">\n<div class="mb6">\n<h3 class="normal mb4 mobile-hide">\nAbout this project\n</h3>\n<div class="mb2">\n<div class="project-image" data-has-video="true" id="video-section">\n<div class="video-player" data-dimensions="{&quot;width&quot;:640,&quot;height&quot;:480}" data-image="https://ksr-ugc.imgix.net/projects/1454788/photo-original.jpg?v=1415141322&amp;w=1024&amp;h=768&amp;fit=crop&amp;auto=format&amp;q=92&amp;s=b5b9ea9cefeb047908fbe79ad0fc787c" data-video-tracker-url="https://www.kickstarter.com/projects/1284004843/the-caretaker-by-harold-pinter/video/plays" data-video-url="https://d2pq0u4uni88oo.cloudfront.net/projects/1454788/video-461757-h264_high.mp4" data-video="{&quot;id&quot;:461757,&quot;status&quot;:&quot;successful&quot;,&quot;high&quot;:&quot;https://d2pq0u4uni88oo.cloudfront.net/projects/1454788/video-461757-h264_high.
# ...

# %%
soup = BeautifulSoup(p.text)

# %%
print soup.prettify()
# Out:
# <div class="NS_projects__description_section">
#  <div class="py6 bg-white">
#   <div class="container-flex px2">
#    <div class="row">
#     <div class="col col-8">
#      <div class="mb6">
#       <h3 class="normal mb4 mobile-hide">
#        About this project
#       </h3>
#       <div class="mb2">
#        <div class="project-image" data-has-video="true" id="video-section">
# ...

# %%
print soup.get_text() #looks great!
# Out:
# About this project
#
#
#
#
#
#
#
# You'll need an HTML5 capable browser to see this content.
#
#
#
#
#
# Play
#
#
#
#
#
#
#
#
# 00:00
#
#
# 00:00
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Durham, NC
#
# Theater
#
#
#
#
#
# $1,101
#
#
# pledged of $1,100 goal
#
#
#
#
#
# ...

# %%
print soup.a
# Out:
# <a class="grey-dark mr3 nowrap" href="/discover/places/durham-nc?ref=city"><span class="ss-icon ss-location margin-right"></span>
# <b>Durham, NC</b>
# </a>
