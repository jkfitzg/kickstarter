# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_curve, auc
from sklearn import grid_search
from sklearn import cross_validation
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
sns.set_context('talk')
sns.set_style('whitegrid')

# %%
# %matplotlib qt

# %%
def plotROCCurve(y_test, prediction_proba):
    fig = plt.figure(figsize=(4,4))
    fpr, tpr, thresholds = roc_curve(y_test, prediction_proba[:,1])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(bbox_to_anchor=(0.9, 0.2),
               bbox_transform=plt.gcf().transFigure)
    plt.savefig('random_forest_aucroc.png', bbox_inches='tight', dpi=200)

# %%
X_df = pd.read_pickle('new_X_df.save')
outcomes_df = pd.read_pickle('new_outcomes_df.save')

# %%
np.shape(X_df)
# Out:
# (115196, 38)

# %%
X_train, X_test, y_train, y_test = \
    cross_validation.train_test_split(X_df, outcomes_df['Outcome'].values, \
                                      test_size=0.25, random_state=2) # was 0

# %%
from sklearn import linear_model
clf = linear_model.LogisticRegression(C=1e5)
clf.fit(X_train,y_train)
# Out:
# LogisticRegression(C=100000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0)

# %%
y_1 = clf.predict(X_test)
y_1_proba = clf.predict_proba(X_test)

# %%
metrics.roc_auc_score(y_test, y_1_proba[:,1]) # average='macro',
# Out:
# 0.75837382543665977

# %%
metrics.accuracy_score(y_test,y_1, normalize=True)
# Out:
# 0.68189867703739715

# %%
metrics.precision_recall_fscore_support(y_test, y_1)
# Out:
# (array([ 0.68172629,  0.68238576]),
#  array([ 0.85845371,  0.43142689]),
#  array([ 0.75995074,  0.52863391]),
#  array([16892, 11907]))

# %%
print metrics.classification_report(y_test, y_1)
# Out:
#              precision    recall  f1-score   support
#
#           0       0.68      0.86      0.76     16892
#           1       0.68      0.43      0.53     11907
#
# avg / total       0.68      0.68      0.66     28799

# %%
plotROCCurve(y_test, y_1_proba)

# %%
print clf.coef_[0]
# Out:
# [ -2.52178455e-05  -2.53854855e-02   3.09377221e-03  -3.48570989e-03
#    3.93891683e-03   4.53088616e-02  -5.48147038e-03   2.89949307e-04
#   -1.72157706e-06  -8.81601777e-04   2.47565450e-02   5.12392773e-03
#    4.31433757e-04   3.11666613e-02   5.65758137e-03   3.70736040e-04
#    6.47317685e-05  -3.04592767e-04   4.66418758e-04  -4.96512615e-04
#   -9.52234881e-04   6.32852058e-04  -6.25482820e-04  -1.19143186e-03
#   -1.28094499e-04   3.55266147e-03  -3.94250945e-04  -1.76284739e-03
#   -5.97344276e-04   1.07860303e-03   3.48564689e-04   4.71123939e-06
#    1.20432353e-04   6.21226158e-05   9.76574202e-05  -4.68909561e-04
#   -1.92976091e-04   9.01730928e-05]

# %%
from plot_suggestions import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plot_coefficients(clf.coef_[0],\
                        X_df.columns,len(clf.coef_[0]))

# %%
best_clf = clf_grid.best_estimator_

# %%
from sklearn.externals import joblib
joblib.dump(best_clf, 'clf_grid_june24pm.pkl')
# Out:
# ['clf_grid_june24pm.pkl',
#  'clf_grid_june24pm.pkl_01.npy',
#  'clf_grid_june24pm.pkl_02.npy',
#  'clf_grid_june24pm.pkl_03.npy',
#  'clf_grid_june24pm.pkl_04.npy',
#  'clf_grid_june24pm.pkl_05.npy',
#  'clf_grid_june24pm.pkl_06.npy',
#  'clf_grid_june24pm.pkl_07.npy',
#  'clf_grid_june24pm.pkl_08.npy',
#  'clf_grid_june24pm.pkl_09.npy',
#  'clf_grid_june24pm.pkl_10.npy',
#  'clf_grid_june24pm.pkl_11.npy',
#  'clf_grid_june24pm.pkl_12.npy',
#  'clf_grid_june24pm.pkl_13.npy',
#  'clf_grid_june24pm.pkl_14.npy',
#  'clf_grid_june24pm.pkl_15.npy',
#  'clf_grid_june24pm.pkl_16.npy',
#  'clf_grid_june24pm.pkl_17.npy',
#  'clf_grid_june24pm.pkl_18.npy',
#  'clf_grid_june24pm.pkl_19.npy',
#  'clf_grid_june24pm.pkl_20.npy',
#  'clf_grid_june24pm.pkl_21.npy',
#  'clf_grid_june24pm.pkl_22.npy',
#  'clf_grid_june24pm.pkl_23.npy',
#  'clf_grid_june24pm.pkl_24.npy',
#  'clf_grid_june24pm.pkl_25.npy',
#  'clf_grid_june24pm.pkl_26.npy',
#  'clf_grid_june24pm.pkl_27.npy',
#  'clf_grid_june24pm.pkl_28.npy',
#  'clf_grid_june24pm.pkl_29.npy',
#  'clf_grid_june24pm.pkl_30.npy',
#  'clf_grid_june24pm.pkl_31.npy',
#  'clf_grid_june24pm.pkl_32.npy',
#  'clf_grid_june24pm.pkl_33.npy',
#  'clf_grid_june24pm.pkl_34.npy',
#  'clf_grid_june24pm.pkl_35.npy',
#  'clf_grid_june24pm.pkl_36.npy',
#  'clf_grid_june24pm.pkl_37.npy',
#  'clf_grid_june24pm.pkl_38.npy',
#  'clf_grid_june24pm.pkl_39.npy',
#  'clf_grid_june24pm.pkl_40.npy',
#  'clf_grid_june24pm.pkl_41.npy',
#  'clf_grid_june24pm.pkl_42.npy',
#  'clf_grid_june24pm.pkl_43.npy',
#  'clf_grid_june24pm.pkl_44.npy',
#  'clf_grid_june24pm.pkl_45.npy',
#  'clf_grid_june24pm.pkl_46.npy',
#  'clf_grid_june24pm.pkl_47.npy',
#  'clf_grid_june24pm.pkl_48.npy',
#  'clf_grid_june24pm.pkl_49.npy',
#  'clf_grid_june24pm.pkl_50.npy',
#  'clf_grid_june24pm.pkl_51.npy',
#  'clf_grid_june24pm.pkl_52.npy',
#  'clf_grid_june24pm.pkl_53.npy',
#  'clf_grid_june24pm.pkl_54.npy',
#  'clf_grid_june24pm.pkl_55.npy',
#  'clf_grid_june24pm.pkl_56.npy',
#  'clf_grid_june24pm.pkl_57.npy',
#  'clf_grid_june24pm.pkl_58.npy',
#  'clf_grid_june24pm.pkl_59.npy',
#  'clf_grid_june24pm.pkl_60.npy',
#  'clf_grid_june24pm.pkl_61.npy',
#  'clf_grid_june24pm.pkl_62.npy',
#  'clf_grid_june24pm.pkl_63.npy',
#  'clf_grid_june24pm.pkl_64.npy',
#  'clf_grid_june24pm.pkl_65.npy',
#  'clf_grid_june24pm.pkl_66.npy',
#  'clf_grid_june24pm.pkl_67.npy',
#  'clf_grid_june24pm.pkl_68.npy',
#  'clf_grid_june24pm.pkl_69.npy',
#  'clf_grid_june24pm.pkl_70.npy',
#  'clf_grid_june24pm.pkl_71.npy',
#  'clf_grid_june24pm.pkl_72.npy',
#  'clf_grid_june24pm.pkl_73.npy',
#  'clf_grid_june24pm.pkl_74.npy',
#  'clf_grid_june24pm.pkl_75.npy',
#  'clf_grid_june24pm.pkl_76.npy',
#  'clf_grid_june24pm.pkl_77.npy',
#  'clf_grid_june24pm.pkl_78.npy',
#  'clf_grid_june24pm.pkl_79.npy',
#  'clf_grid_june24pm.pkl_80.npy',
#  'clf_grid_june24pm.pkl_81.npy',
#  'clf_grid_june24pm.pkl_82.npy',
#  'clf_grid_june24pm.pkl_83.npy',
#  'clf_grid_june24pm.pkl_84.npy',
#  'clf_grid_june24pm.pkl_85.npy',
#  'clf_grid_june24pm.pkl_86.npy',
#  'clf_grid_june24pm.pkl_87.npy',
#  'clf_grid_june24pm.pkl_88.npy',
#  'clf_grid_june24pm.pkl_89.npy',
#  'clf_grid_june24pm.pkl_90.npy',
#  'clf_grid_june24pm.pkl_91.npy',
#  'clf_grid_june24pm.pkl_92.npy',
#  'clf_grid_june24pm.pkl_93.npy',
#  'clf_grid_june24pm.pkl_94.npy',
#  'clf_grid_june24pm.pkl_95.npy',
#  'clf_grid_june24pm.pkl_96.npy',
#  'clf_grid_june24pm.pkl_97.npy',
#  'clf_grid_june24pm.pkl_98.npy',
#  'clf_grid_june24pm.pkl_99.npy',
#  'clf_grid_june24pm.pkl_100.npy',
#  'clf_grid_june24pm.pkl_101.npy',
#  'clf_grid_june24pm.pkl_102.npy',
#  'clf_grid_june24pm.pkl_103.npy',
#  'clf_grid_june24pm.pkl_104.npy',
#  'clf_grid_june24pm.pkl_105.npy',
#  'clf_grid_june24pm.pkl_106.npy',
#  'clf_grid_june24pm.pkl_107.npy',
#  'clf_grid_june24pm.pkl_108.npy',
#  'clf_grid_june24pm.pkl_109.npy',
#  'clf_grid_june24pm.pkl_110.npy',
#  'clf_grid_june24pm.pkl_111.npy',
#  'clf_grid_june24pm.pkl_112.npy',
#  'clf_grid_june24pm.pkl_113.npy',
#  'clf_grid_june24pm.pkl_114.npy',
#  'clf_grid_june24pm.pkl_115.npy',
#  'clf_grid_june24pm.pkl_116.npy',
#  'clf_grid_june24pm.pkl_117.npy',
#  'clf_grid_june24pm.pkl_118.npy',
#  'clf_grid_june24pm.pkl_119.npy',
#  'clf_grid_june24pm.pkl_120.npy',
#  'clf_grid_june24pm.pkl_121.npy',
#  'clf_grid_june24pm.pkl_122.npy',
#  'clf_grid_june24pm.pkl_123.npy',
#  'clf_grid_june24pm.pkl_124.npy',
#  'clf_grid_june24pm.pkl_125.npy',
#  'clf_grid_june24pm.pkl_126.npy',
#  'clf_grid_june24pm.pkl_127.npy',
#  'clf_grid_june24pm.pkl_128.npy',
#  'clf_grid_june24pm.pkl_129.npy',
#  'clf_grid_june24pm.pkl_130.npy',
#  'clf_grid_june24pm.pkl_131.npy',
#  'clf_grid_june24pm.pkl_132.npy',
#  'clf_grid_june24pm.pkl_133.npy',
#  'clf_grid_june24pm.pkl_134.npy',
#  'clf_grid_june24pm.pkl_135.npy',
#  'clf_grid_june24pm.pkl_136.npy',
#  'clf_grid_june24pm.pkl_137.npy',
#  'clf_grid_june24pm.pkl_138.npy',
#  'clf_grid_june24pm.pkl_139.npy',
#  'clf_grid_june24pm.pkl_140.npy',
#  'clf_grid_june24pm.pkl_141.npy',
#  'clf_grid_june24pm.pkl_142.npy',
#  'clf_grid_june24pm.pkl_143.npy',
#  'clf_grid_june24pm.pkl_144.npy',
#  'clf_grid_june24pm.pkl_145.npy',
#  'clf_grid_june24pm.pkl_146.npy',
#  'clf_grid_june24pm.pkl_147.npy',
#  'clf_grid_june24pm.pkl_148.npy',
#  'clf_grid_june24pm.pkl_149.npy',
#  'clf_grid_june24pm.pkl_150.npy',
#  'clf_grid_june24pm.pkl_151.npy',
#  'clf_grid_june24pm.pkl_152.npy',
#  'clf_grid_june24pm.pkl_153.npy',
#  'clf_grid_june24pm.pkl_154.npy',
#  'clf_grid_june24pm.pkl_155.npy',
#  'clf_grid_june24pm.pkl_156.npy',
#  'clf_grid_june24pm.pkl_157.npy',
#  'clf_grid_june24pm.pkl_158.npy',
#  'clf_grid_june24pm.pkl_159.npy',
#  'clf_grid_june24pm.pkl_160.npy',
#  'clf_grid_june24pm.pkl_161.npy',
#  'clf_grid_june24pm.pkl_162.npy',
#  'clf_grid_june24pm.pkl_163.npy',
#  'clf_grid_june24pm.pkl_164.npy',
#  'clf_grid_june24pm.pkl_165.npy',
#  'clf_grid_june24pm.pkl_166.npy',
#  'clf_grid_june24pm.pkl_167.npy',
#  'clf_grid_june24pm.pkl_168.npy',
#  'clf_grid_june24pm.pkl_169.npy',
#  'clf_grid_june24pm.pkl_170.npy',
#  'clf_grid_june24pm.pkl_171.npy',
#  'clf_grid_june24pm.pkl_172.npy',
#  'clf_grid_june24pm.pkl_173.npy',
#  'clf_grid_june24pm.pkl_174.npy',
#  'clf_grid_june24pm.pkl_175.npy',
#  'clf_grid_june24pm.pkl_176.npy',
#  'clf_grid_june24pm.pkl_177.npy',
#  'clf_grid_june24pm.pkl_178.npy',
#  'clf_grid_june24pm.pkl_179.npy',
#  'clf_grid_june24pm.pkl_180.npy',
#  'clf_grid_june24pm.pkl_181.npy',
#  'clf_grid_june24pm.pkl_182.npy',
#  'clf_grid_june24pm.pkl_183.npy',
#  'clf_grid_june24pm.pkl_184.npy',
#  'clf_grid_june24pm.pkl_185.npy',
#  'clf_grid_june24pm.pkl_186.npy',
#  'clf_grid_june24pm.pkl_187.npy',
#  'clf_grid_june24pm.pkl_188.npy',
#  'clf_grid_june24pm.pkl_189.npy',
#  'clf_grid_june24pm.pkl_190.npy',
#  'clf_grid_june24pm.pkl_191.npy',
#  'clf_grid_june24pm.pkl_192.npy',
#  'clf_grid_june24pm.pkl_193.npy',
#  'clf_grid_june24pm.pkl_194.npy',
#  'clf_grid_june24pm.pkl_195.npy',
#  'clf_grid_june24pm.pkl_196.npy',
#  'clf_grid_june24pm.pkl_197.npy',
#  'clf_grid_june24pm.pkl_198.npy',
#  'clf_grid_june24pm.pkl_199.npy',
#  'clf_grid_june24pm.pkl_200.npy',
#  'clf_grid_june24pm.pkl_201.npy',
#  'clf_grid_june24pm.pkl_202.npy',
#  'clf_grid_june24pm.pkl_203.npy',
#  'clf_grid_june24pm.pkl_204.npy',
#  'clf_grid_june24pm.pkl_205.npy',
#  'clf_grid_june24pm.pkl_206.npy',
#  'clf_grid_june24pm.pkl_207.npy',
#  'clf_grid_june24pm.pkl_208.npy',
#  'clf_grid_june24pm.pkl_209.npy',
#  'clf_grid_june24pm.pkl_210.npy',
#  'clf_grid_june24pm.pkl_211.npy',
#  'clf_grid_june24pm.pkl_212.npy',
#  'clf_grid_june24pm.pkl_213.npy',
#  'clf_grid_june24pm.pkl_214.npy',
#  'clf_grid_june24pm.pkl_215.npy',
#  'clf_grid_june24pm.pkl_216.npy',
#  'clf_grid_june24pm.pkl_217.npy',
#  'clf_grid_june24pm.pkl_218.npy',
#  'clf_grid_june24pm.pkl_219.npy',
#  'clf_grid_june24pm.pkl_220.npy',
#  'clf_grid_june24pm.pkl_221.npy',
#  'clf_grid_june24pm.pkl_222.npy',
#  'clf_grid_june24pm.pkl_223.npy',
#  'clf_grid_june24pm.pkl_224.npy',
#  'clf_grid_june24pm.pkl_225.npy',
#  'clf_grid_june24pm.pkl_226.npy',
#  'clf_grid_june24pm.pkl_227.npy',
#  'clf_grid_june24pm.pkl_228.npy',
#  'clf_grid_june24pm.pkl_229.npy',
#  'clf_grid_june24pm.pkl_230.npy',
#  'clf_grid_june24pm.pkl_231.npy',
#  'clf_grid_june24pm.pkl_232.npy',
#  'clf_grid_june24pm.pkl_233.npy',
#  'clf_grid_june24pm.pkl_234.npy',
#  'clf_grid_june24pm.pkl_235.npy',
#  'clf_grid_june24pm.pkl_236.npy',
#  'clf_grid_june24pm.pkl_237.npy',
#  'clf_grid_june24pm.pkl_238.npy',
#  'clf_grid_june24pm.pkl_239.npy',
#  'clf_grid_june24pm.pkl_240.npy',
#  'clf_grid_june24pm.pkl_241.npy',
#  'clf_grid_june24pm.pkl_242.npy',
#  'clf_grid_june24pm.pkl_243.npy',
#  'clf_grid_june24pm.pkl_244.npy',
#  'clf_grid_june24pm.pkl_245.npy',
#  'clf_grid_june24pm.pkl_246.npy',
#  'clf_grid_june24pm.pkl_247.npy',
#  'clf_grid_june24pm.pkl_248.npy',
#  'clf_grid_june24pm.pkl_249.npy',
#  'clf_grid_june24pm.pkl_250.npy',
#  'clf_grid_june24pm.pkl_251.npy',
#  'clf_grid_june24pm.pkl_252.npy',
#  'clf_grid_june24pm.pkl_253.npy',
#  'clf_grid_june24pm.pkl_254.npy',
#  'clf_grid_june24pm.pkl_255.npy',
#  'clf_grid_june24pm.pkl_256.npy',
#  'clf_grid_june24pm.pkl_257.npy',
#  'clf_grid_june24pm.pkl_258.npy',
#  'clf_grid_june24pm.pkl_259.npy',
#  'clf_grid_june24pm.pkl_260.npy',
#  'clf_grid_june24pm.pkl_261.npy',
#  'clf_grid_june24pm.pkl_262.npy',
#  'clf_grid_june24pm.pkl_263.npy',
#  'clf_grid_june24pm.pkl_264.npy',
#  'clf_grid_june24pm.pkl_265.npy',
#  'clf_grid_june24pm.pkl_266.npy',
#  'clf_grid_june24pm.pkl_267.npy',
#  'clf_grid_june24pm.pkl_268.npy',
#  'clf_grid_june24pm.pkl_269.npy',
#  'clf_grid_june24pm.pkl_270.npy',
#  'clf_grid_june24pm.pkl_271.npy',
#  'clf_grid_june24pm.pkl_272.npy',
#  'clf_grid_june24pm.pkl_273.npy',
#  'clf_grid_june24pm.pkl_274.npy',
#  'clf_grid_june24pm.pkl_275.npy',
#  'clf_grid_june24pm.pkl_276.npy',
#  'clf_grid_june24pm.pkl_277.npy',
#  'clf_grid_june24pm.pkl_278.npy',
#  'clf_grid_june24pm.pkl_279.npy',
#  'clf_grid_june24pm.pkl_280.npy',
#  'clf_grid_june24pm.pkl_281.npy',
#  'clf_grid_june24pm.pkl_282.npy',
#  'clf_grid_june24pm.pkl_283.npy',
#  'clf_grid_june24pm.pkl_284.npy',
#  'clf_grid_june24pm.pkl_285.npy',
#  'clf_grid_june24pm.pkl_286.npy',
#  'clf_grid_june24pm.pkl_287.npy',
#  'clf_grid_june24pm.pkl_288.npy',
#  'clf_grid_june24pm.pkl_289.npy',
#  'clf_grid_june24pm.pkl_290.npy',
#  'clf_grid_june24pm.pkl_291.npy',
#  'clf_grid_june24pm.pkl_292.npy',
#  'clf_grid_june24pm.pkl_293.npy',
#  'clf_grid_june24pm.pkl_294.npy',
#  'clf_grid_june24pm.pkl_295.npy',
#  'clf_grid_june24pm.pkl_296.npy',
#  'clf_grid_june24pm.pkl_297.npy',
#  'clf_grid_june24pm.pkl_298.npy',
#  'clf_grid_june24pm.pkl_299.npy',
#  'clf_grid_june24pm.pkl_300.npy',
#  'clf_grid_june24pm.pkl_301.npy',
#  'clf_grid_june24pm.pkl_302.npy',
#  'clf_grid_june24pm.pkl_303.npy',
#  'clf_grid_june24pm.pkl_304.npy',
#  'clf_grid_june24pm.pkl_305.npy',
#  'clf_grid_june24pm.pkl_306.npy',
#  'clf_grid_june24pm.pkl_307.npy',
#  'clf_grid_june24pm.pkl_308.npy',
#  'clf_grid_june24pm.pkl_309.npy',
#  'clf_grid_june24pm.pkl_310.npy',
#  'clf_grid_june24pm.pkl_311.npy',
#  'clf_grid_june24pm.pkl_312.npy',
#  'clf_grid_june24pm.pkl_313.npy',
#  'clf_grid_june24pm.pkl_314.npy',
#  'clf_grid_june24pm.pkl_315.npy',
#  'clf_grid_june24pm.pkl_316.npy',
#  'clf_grid_june24pm.pkl_317.npy',
#  'clf_grid_june24pm.pkl_318.npy',
#  'clf_grid_june24pm.pkl_319.npy',
#  'clf_grid_june24pm.pkl_320.npy',
#  'clf_grid_june24pm.pkl_321.npy',
#  'clf_grid_june24pm.pkl_322.npy',
#  'clf_grid_june24pm.pkl_323.npy',
#  'clf_grid_june24pm.pkl_324.npy',
#  'clf_grid_june24pm.pkl_325.npy',
#  'clf_grid_june24pm.pkl_326.npy',
#  'clf_grid_june24pm.pkl_327.npy',
#  'clf_grid_june24pm.pkl_328.npy',
#  'clf_grid_june24pm.pkl_329.npy',
#  'clf_grid_june24pm.pkl_330.npy',
#  'clf_grid_june24pm.pkl_331.npy',
#  'clf_grid_june24pm.pkl_332.npy',
#  'clf_grid_june24pm.pkl_333.npy',
#  'clf_grid_june24pm.pkl_334.npy',
#  'clf_grid_june24pm.pkl_335.npy',
#  'clf_grid_june24pm.pkl_336.npy',
#  'clf_grid_june24pm.pkl_337.npy',
#  'clf_grid_june24pm.pkl_338.npy',
#  'clf_grid_june24pm.pkl_339.npy',
#  'clf_grid_june24pm.pkl_340.npy',
#  'clf_grid_june24pm.pkl_341.npy',
#  'clf_grid_june24pm.pkl_342.npy',
#  'clf_grid_june24pm.pkl_343.npy',
#  'clf_grid_june24pm.pkl_344.npy',
#  'clf_grid_june24pm.pkl_345.npy',
#  'clf_grid_june24pm.pkl_346.npy',
#  'clf_grid_june24pm.pkl_347.npy',
#  'clf_grid_june24pm.pkl_348.npy',
#  'clf_grid_june24pm.pkl_349.npy',
#  'clf_grid_june24pm.pkl_350.npy',
#  'clf_grid_june24pm.pkl_351.npy',
#  'clf_grid_june24pm.pkl_352.npy',
#  'clf_grid_june24pm.pkl_353.npy',
#  'clf_grid_june24pm.pkl_354.npy',
#  'clf_grid_june24pm.pkl_355.npy',
#  'clf_grid_june24pm.pkl_356.npy',
#  'clf_grid_june24pm.pkl_357.npy',
#  'clf_grid_june24pm.pkl_358.npy',
#  'clf_grid_june24pm.pkl_359.npy',
#  'clf_grid_june24pm.pkl_360.npy',
#  'clf_grid_june24pm.pkl_361.npy',
#  'clf_grid_june24pm.pkl_362.npy',
#  'clf_grid_june24pm.pkl_363.npy',
#  'clf_grid_june24pm.pkl_364.npy',
#  'clf_grid_june24pm.pkl_365.npy',
#  'clf_grid_june24pm.pkl_366.npy',
#  'clf_grid_june24pm.pkl_367.npy',
#  'clf_grid_june24pm.pkl_368.npy',
#  'clf_grid_june24pm.pkl_369.npy',
#  'clf_grid_june24pm.pkl_370.npy',
#  'clf_grid_june24pm.pkl_371.npy',
#  'clf_grid_june24pm.pkl_372.npy',
#  'clf_grid_june24pm.pkl_373.npy',
#  'clf_grid_june24pm.pkl_374.npy',
#  'clf_grid_june24pm.pkl_375.npy',
#  'clf_grid_june24pm.pkl_376.npy',
#  'clf_grid_june24pm.pkl_377.npy',
#  'clf_grid_june24pm.pkl_378.npy',
#  'clf_grid_june24pm.pkl_379.npy',
#  'clf_grid_june24pm.pkl_380.npy',
#  'clf_grid_june24pm.pkl_381.npy',
#  'clf_grid_june24pm.pkl_382.npy',
#  'clf_grid_june24pm.pkl_383.npy',
#  'clf_grid_june24pm.pkl_384.npy',
#  'clf_grid_june24pm.pkl_385.npy',
#  'clf_grid_june24pm.pkl_386.npy',
#  'clf_grid_june24pm.pkl_387.npy',
#  'clf_grid_june24pm.pkl_388.npy',
#  'clf_grid_june24pm.pkl_389.npy',
#  'clf_grid_june24pm.pkl_390.npy',
#  'clf_grid_june24pm.pkl_391.npy',
#  'clf_grid_june24pm.pkl_392.npy',
#  'clf_grid_june24pm.pkl_393.npy',
#  'clf_grid_june24pm.pkl_394.npy',
#  'clf_grid_june24pm.pkl_395.npy',
#  'clf_grid_june24pm.pkl_396.npy',
#  'clf_grid_june24pm.pkl_397.npy',
#  'clf_grid_june24pm.pkl_398.npy',
#  'clf_grid_june24pm.pkl_399.npy',
#  'clf_grid_june24pm.pkl_400.npy',
#  'clf_grid_june24pm.pkl_401.npy',
#  'clf_grid_june24pm.pkl_402.npy',
#  'clf_grid_june24pm.pkl_403.npy',
#  'clf_grid_june24pm.pkl_404.npy',
#  'clf_grid_june24pm.pkl_405.npy',
#  'clf_grid_june24pm.pkl_406.npy',
#  'clf_grid_june24pm.pkl_407.npy',
#  'clf_grid_june24pm.pkl_408.npy',
#  'clf_grid_june24pm.pkl_409.npy',
#  'clf_grid_june24pm.pkl_410.npy',
#  'clf_grid_june24pm.pkl_411.npy',
#  'clf_grid_june24pm.pkl_412.npy',
#  'clf_grid_june24pm.pkl_413.npy',
#  'clf_grid_june24pm.pkl_414.npy',
#  'clf_grid_june24pm.pkl_415.npy',
#  'clf_grid_june24pm.pkl_416.npy',
#  'clf_grid_june24pm.pkl_417.npy',
#  'clf_grid_june24pm.pkl_418.npy',
#  'clf_grid_june24pm.pkl_419.npy',
#  'clf_grid_june24pm.pkl_420.npy',
#  'clf_grid_june24pm.pkl_421.npy',
#  'clf_grid_june24pm.pkl_422.npy',
#  'clf_grid_june24pm.pkl_423.npy',
#  'clf_grid_june24pm.pkl_424.npy',
#  'clf_grid_june24pm.pkl_425.npy',
#  'clf_grid_june24pm.pkl_426.npy',
#  'clf_grid_june24pm.pkl_427.npy',
#  'clf_grid_june24pm.pkl_428.npy',
#  'clf_grid_june24pm.pkl_429.npy',
#  'clf_grid_june24pm.pkl_430.npy',
#  'clf_grid_june24pm.pkl_431.npy',
#  'clf_grid_june24pm.pkl_432.npy',
#  'clf_grid_june24pm.pkl_433.npy',
#  'clf_grid_june24pm.pkl_434.npy',
#  'clf_grid_june24pm.pkl_435.npy',
#  'clf_grid_june24pm.pkl_436.npy',
#  'clf_grid_june24pm.pkl_437.npy',
#  'clf_grid_june24pm.pkl_438.npy',
#  'clf_grid_june24pm.pkl_439.npy',
#  'clf_grid_june24pm.pkl_440.npy',
#  'clf_grid_june24pm.pkl_441.npy',
#  'clf_grid_june24pm.pkl_442.npy',
#  'clf_grid_june24pm.pkl_443.npy',
#  'clf_grid_june24pm.pkl_444.npy',
#  'clf_grid_june24pm.pkl_445.npy',
#  'clf_grid_june24pm.pkl_446.npy',
#  'clf_grid_june24pm.pkl_447.npy',
#  'clf_grid_june24pm.pkl_448.npy',
#  'clf_grid_june24pm.pkl_449.npy',
#  'clf_grid_june24pm.pkl_450.npy',
#  'clf_grid_june24pm.pkl_451.npy',
#  'clf_grid_june24pm.pkl_452.npy',
#  'clf_grid_june24pm.pkl_453.npy',
#  'clf_grid_june24pm.pkl_454.npy',
#  'clf_grid_june24pm.pkl_455.npy',
#  'clf_grid_june24pm.pkl_456.npy',
#  'clf_grid_june24pm.pkl_457.npy',
#  'clf_grid_june24pm.pkl_458.npy',
#  'clf_grid_june24pm.pkl_459.npy',
#  'clf_grid_june24pm.pkl_460.npy',
#  'clf_grid_june24pm.pkl_461.npy',
#  'clf_grid_june24pm.pkl_462.npy',
#  'clf_grid_june24pm.pkl_463.npy',
#  'clf_grid_june24pm.pkl_464.npy',
#  'clf_grid_june24pm.pkl_465.npy',
#  'clf_grid_june24pm.pkl_466.npy',
#  'clf_grid_june24pm.pkl_467.npy',
#  'clf_grid_june24pm.pkl_468.npy',
#  'clf_grid_june24pm.pkl_469.npy',
#  'clf_grid_june24pm.pkl_470.npy',
#  'clf_grid_june24pm.pkl_471.npy',
#  'clf_grid_june24pm.pkl_472.npy',
#  'clf_grid_june24pm.pkl_473.npy',
#  'clf_grid_june24pm.pkl_474.npy',
#  'clf_grid_june24pm.pkl_475.npy',
#  'clf_grid_june24pm.pkl_476.npy',
#  'clf_grid_june24pm.pkl_477.npy',
#  'clf_grid_june24pm.pkl_478.npy',
#  'clf_grid_june24pm.pkl_479.npy',
#  'clf_grid_june24pm.pkl_480.npy',
#  'clf_grid_june24pm.pkl_481.npy',
#  'clf_grid_june24pm.pkl_482.npy',
#  'clf_grid_june24pm.pkl_483.npy',
#  'clf_grid_june24pm.pkl_484.npy',
#  'clf_grid_june24pm.pkl_485.npy',
#  'clf_grid_june24pm.pkl_486.npy',
#  'clf_grid_june24pm.pkl_487.npy',
#  'clf_grid_june24pm.pkl_488.npy',
#  'clf_grid_june24pm.pkl_489.npy',
#  'clf_grid_june24pm.pkl_490.npy',
#  'clf_grid_june24pm.pkl_491.npy',
#  'clf_grid_june24pm.pkl_492.npy',
#  'clf_grid_june24pm.pkl_493.npy',
#  'clf_grid_june24pm.pkl_494.npy',
#  'clf_grid_june24pm.pkl_495.npy',
#  'clf_grid_june24pm.pkl_496.npy',
#  'clf_grid_june24pm.pkl_497.npy',
#  'clf_grid_june24pm.pkl_498.npy',
#  'clf_grid_june24pm.pkl_499.npy',
#  'clf_grid_june24pm.pkl_500.npy',
#  'clf_grid_june24pm.pkl_501.npy',
#  'clf_grid_june24pm.pkl_502.npy',
#  'clf_grid_june24pm.pkl_503.npy',
#  'clf_grid_june24pm.pkl_504.npy',
#  'clf_grid_june24pm.pkl_505.npy',
#  'clf_grid_june24pm.pkl_506.npy',
#  'clf_grid_june24pm.pkl_507.npy',
#  'clf_grid_june24pm.pkl_508.npy',
#  'clf_grid_june24pm.pkl_509.npy',
#  'clf_grid_june24pm.pkl_510.npy',
#  'clf_grid_june24pm.pkl_511.npy',
#  'clf_grid_june24pm.pkl_512.npy',
#  'clf_grid_june24pm.pkl_513.npy',
#  'clf_grid_june24pm.pkl_514.npy',
#  'clf_grid_june24pm.pkl_515.npy',
#  'clf_grid_june24pm.pkl_516.npy',
#  'clf_grid_june24pm.pkl_517.npy',
#  'clf_grid_june24pm.pkl_518.npy',
#  'clf_grid_june24pm.pkl_519.npy',
#  'clf_grid_june24pm.pkl_520.npy',
#  'clf_grid_june24pm.pkl_521.npy',
#  'clf_grid_june24pm.pkl_522.npy',
#  'clf_grid_june24pm.pkl_523.npy',
#  'clf_grid_june24pm.pkl_524.npy',
#  'clf_grid_june24pm.pkl_525.npy',
#  'clf_grid_june24pm.pkl_526.npy',
#  'clf_grid_june24pm.pkl_527.npy',
#  'clf_grid_june24pm.pkl_528.npy',
#  'clf_grid_june24pm.pkl_529.npy',
#  'clf_grid_june24pm.pkl_530.npy',
#  'clf_grid_june24pm.pkl_531.npy',
#  'clf_grid_june24pm.pkl_532.npy',
#  'clf_grid_june24pm.pkl_533.npy',
#  'clf_grid_june24pm.pkl_534.npy',
#  'clf_grid_june24pm.pkl_535.npy',
#  'clf_grid_june24pm.pkl_536.npy',
#  'clf_grid_june24pm.pkl_537.npy',
#  'clf_grid_june24pm.pkl_538.npy',
#  'clf_grid_june24pm.pkl_539.npy',
#  'clf_grid_june24pm.pkl_540.npy',
#  'clf_grid_june24pm.pkl_541.npy',
#  'clf_grid_june24pm.pkl_542.npy',
#  'clf_grid_june24pm.pkl_543.npy',
#  'clf_grid_june24pm.pkl_544.npy',
#  'clf_grid_june24pm.pkl_545.npy',
#  'clf_grid_june24pm.pkl_546.npy',
#  'clf_grid_june24pm.pkl_547.npy',
#  'clf_grid_june24pm.pkl_548.npy',
#  'clf_grid_june24pm.pkl_549.npy',
#  'clf_grid_june24pm.pkl_550.npy',
#  'clf_grid_june24pm.pkl_551.npy',
#  'clf_grid_june24pm.pkl_552.npy',
#  'clf_grid_june24pm.pkl_553.npy',
#  'clf_grid_june24pm.pkl_554.npy',
#  'clf_grid_june24pm.pkl_555.npy',
#  'clf_grid_june24pm.pkl_556.npy',
#  'clf_grid_june24pm.pkl_557.npy',
#  'clf_grid_june24pm.pkl_558.npy',
#  'clf_grid_june24pm.pkl_559.npy',
#  'clf_grid_june24pm.pkl_560.npy',
#  'clf_grid_june24pm.pkl_561.npy',
#  'clf_grid_june24pm.pkl_562.npy',
#  'clf_grid_june24pm.pkl_563.npy',
#  'clf_grid_june24pm.pkl_564.npy',
#  'clf_grid_june24pm.pkl_565.npy',
#  'clf_grid_june24pm.pkl_566.npy',
#  'clf_grid_june24pm.pkl_567.npy',
#  'clf_grid_june24pm.pkl_568.npy',
#  'clf_grid_june24pm.pkl_569.npy',
#  'clf_grid_june24pm.pkl_570.npy',
#  'clf_grid_june24pm.pkl_571.npy',
#  'clf_grid_june24pm.pkl_572.npy',
#  'clf_grid_june24pm.pkl_573.npy',
#  'clf_grid_june24pm.pkl_574.npy',
#  'clf_grid_june24pm.pkl_575.npy',
#  'clf_grid_june24pm.pkl_576.npy',
#  'clf_grid_june24pm.pkl_577.npy',
#  'clf_grid_june24pm.pkl_578.npy',
#  'clf_grid_june24pm.pkl_579.npy',
#  'clf_grid_june24pm.pkl_580.npy',
#  'clf_grid_june24pm.pkl_581.npy',
#  'clf_grid_june24pm.pkl_582.npy',
#  'clf_grid_june24pm.pkl_583.npy',
#  'clf_grid_june24pm.pkl_584.npy',
#  'clf_grid_june24pm.pkl_585.npy',
#  'clf_grid_june24pm.pkl_586.npy',
#  'clf_grid_june24pm.pkl_587.npy',
#  'clf_grid_june24pm.pkl_588.npy',
#  'clf_grid_june24pm.pkl_589.npy',
#  'clf_grid_june24pm.pkl_590.npy',
#  'clf_grid_june24pm.pkl_591.npy',
#  'clf_grid_june24pm.pkl_592.npy',
#  'clf_grid_june24pm.pkl_593.npy',
#  'clf_grid_june24pm.pkl_594.npy',
#  'clf_grid_june24pm.pkl_595.npy',
#  'clf_grid_june24pm.pkl_596.npy',
#  'clf_grid_june24pm.pkl_597.npy',
#  'clf_grid_june24pm.pkl_598.npy',
#  'clf_grid_june24pm.pkl_599.npy',
#  'clf_grid_june24pm.pkl_600.npy',
#  'clf_grid_june24pm.pkl_601.npy',
#  'clf_grid_june24pm.pkl_602.npy',
#  'clf_grid_june24pm.pkl_603.npy',
#  'clf_grid_june24pm.pkl_604.npy',
#  'clf_grid_june24pm.pkl_605.npy',
#  'clf_grid_june24pm.pkl_606.npy',
#  'clf_grid_june24pm.pkl_607.npy',
#  'clf_grid_june24pm.pkl_608.npy',
#  'clf_grid_june24pm.pkl_609.npy',
#  'clf_grid_june24pm.pkl_610.npy',
#  'clf_grid_june24pm.pkl_611.npy',
#  'clf_grid_june24pm.pkl_612.npy',
#  'clf_grid_june24pm.pkl_613.npy',
#  'clf_grid_june24pm.pkl_614.npy',
#  'clf_grid_june24pm.pkl_615.npy',
#  'clf_grid_june24pm.pkl_616.npy',
#  'clf_grid_june24pm.pkl_617.npy',
#  'clf_grid_june24pm.pkl_618.npy',
#  'clf_grid_june24pm.pkl_619.npy',
#  'clf_grid_june24pm.pkl_620.npy',
#  'clf_grid_june24pm.pkl_621.npy',
#  'clf_grid_june24pm.pkl_622.npy',
#  'clf_grid_june24pm.pkl_623.npy',
#  'clf_grid_june24pm.pkl_624.npy',
#  'clf_grid_june24pm.pkl_625.npy',
#  'clf_grid_june24pm.pkl_626.npy',
#  'clf_grid_june24pm.pkl_627.npy',
#  'clf_grid_june24pm.pkl_628.npy',
#  'clf_grid_june24pm.pkl_629.npy',
#  'clf_grid_june24pm.pkl_630.npy',
#  'clf_grid_june24pm.pkl_631.npy',
#  'clf_grid_june24pm.pkl_632.npy',
#  'clf_grid_june24pm.pkl_633.npy',
#  'clf_grid_june24pm.pkl_634.npy',
#  'clf_grid_june24pm.pkl_635.npy',
#  'clf_grid_june24pm.pkl_636.npy',
#  'clf_grid_june24pm.pkl_637.npy',
#  'clf_grid_june24pm.pkl_638.npy',
#  'clf_grid_june24pm.pkl_639.npy',
#  'clf_grid_june24pm.pkl_640.npy',
#  'clf_grid_june24pm.pkl_641.npy',
#  'clf_grid_june24pm.pkl_642.npy',
#  'clf_grid_june24pm.pkl_643.npy',
#  'clf_grid_june24pm.pkl_644.npy',
#  'clf_grid_june24pm.pkl_645.npy',
#  'clf_grid_june24pm.pkl_646.npy',
#  'clf_grid_june24pm.pkl_647.npy',
#  'clf_grid_june24pm.pkl_648.npy',
#  'clf_grid_june24pm.pkl_649.npy',
#  'clf_grid_june24pm.pkl_650.npy',
#  'clf_grid_june24pm.pkl_651.npy',
#  'clf_grid_june24pm.pkl_652.npy',
#  'clf_grid_june24pm.pkl_653.npy',
#  'clf_grid_june24pm.pkl_654.npy',
#  'clf_grid_june24pm.pkl_655.npy',
#  'clf_grid_june24pm.pkl_656.npy',
#  'clf_grid_june24pm.pkl_657.npy',
#  'clf_grid_june24pm.pkl_658.npy',
#  'clf_grid_june24pm.pkl_659.npy',
#  'clf_grid_june24pm.pkl_660.npy',
#  'clf_grid_june24pm.pkl_661.npy',
#  'clf_grid_june24pm.pkl_662.npy',
#  'clf_grid_june24pm.pkl_663.npy',
#  'clf_grid_june24pm.pkl_664.npy',
#  'clf_grid_june24pm.pkl_665.npy',
#  'clf_grid_june24pm.pkl_666.npy',
#  'clf_grid_june24pm.pkl_667.npy',
#  'clf_grid_june24pm.pkl_668.npy',
#  'clf_grid_june24pm.pkl_669.npy',
#  'clf_grid_june24pm.pkl_670.npy',
#  'clf_grid_june24pm.pkl_671.npy',
#  'clf_grid_june24pm.pkl_672.npy',
#  'clf_grid_june24pm.pkl_673.npy',
#  'clf_grid_june24pm.pkl_674.npy',
#  'clf_grid_june24pm.pkl_675.npy',
#  'clf_grid_june24pm.pkl_676.npy',
#  'clf_grid_june24pm.pkl_677.npy',
#  'clf_grid_june24pm.pkl_678.npy',
#  'clf_grid_june24pm.pkl_679.npy',
#  'clf_grid_june24pm.pkl_680.npy',
#  'clf_grid_june24pm.pkl_681.npy',
#  'clf_grid_june24pm.pkl_682.npy',
#  'clf_grid_june24pm.pkl_683.npy',
#  'clf_grid_june24pm.pkl_684.npy',
#  'clf_grid_june24pm.pkl_685.npy',
#  'clf_grid_june24pm.pkl_686.npy',
#  'clf_grid_june24pm.pkl_687.npy',
#  'clf_grid_june24pm.pkl_688.npy',
#  'clf_grid_june24pm.pkl_689.npy',
#  'clf_grid_june24pm.pkl_690.npy',
#  'clf_grid_june24pm.pkl_691.npy',
#  'clf_grid_june24pm.pkl_692.npy',
#  'clf_grid_june24pm.pkl_693.npy',
#  'clf_grid_june24pm.pkl_694.npy',
#  'clf_grid_june24pm.pkl_695.npy',
#  'clf_grid_june24pm.pkl_696.npy',
#  'clf_grid_june24pm.pkl_697.npy',
#  'clf_grid_june24pm.pkl_698.npy',
#  'clf_grid_june24pm.pkl_699.npy',
#  'clf_grid_june24pm.pkl_700.npy',
#  'clf_grid_june24pm.pkl_701.npy',
#  'clf_grid_june24pm.pkl_702.npy',
#  'clf_grid_june24pm.pkl_703.npy',
#  'clf_grid_june24pm.pkl_704.npy',
#  'clf_grid_june24pm.pkl_705.npy',
#  'clf_grid_june24pm.pkl_706.npy',
#  'clf_grid_june24pm.pkl_707.npy',
#  'clf_grid_june24pm.pkl_708.npy',
#  'clf_grid_june24pm.pkl_709.npy',
#  'clf_grid_june24pm.pkl_710.npy',
#  'clf_grid_june24pm.pkl_711.npy',
#  'clf_grid_june24pm.pkl_712.npy',
#  'clf_grid_june24pm.pkl_713.npy',
#  'clf_grid_june24pm.pkl_714.npy',
#  'clf_grid_june24pm.pkl_715.npy',
#  'clf_grid_june24pm.pkl_716.npy',
#  'clf_grid_june24pm.pkl_717.npy',
#  'clf_grid_june24pm.pkl_718.npy',
#  'clf_grid_june24pm.pkl_719.npy',
#  'clf_grid_june24pm.pkl_720.npy',
#  'clf_grid_june24pm.pkl_721.npy',
#  'clf_grid_june24pm.pkl_722.npy',
#  'clf_grid_june24pm.pkl_723.npy',
#  'clf_grid_june24pm.pkl_724.npy',
#  'clf_grid_june24pm.pkl_725.npy',
#  'clf_grid_june24pm.pkl_726.npy',
#  'clf_grid_june24pm.pkl_727.npy',
#  'clf_grid_june24pm.pkl_728.npy',
#  'clf_grid_june24pm.pkl_729.npy',
#  'clf_grid_june24pm.pkl_730.npy',
#  'clf_grid_june24pm.pkl_731.npy',
#  'clf_grid_june24pm.pkl_732.npy',
#  'clf_grid_june24pm.pkl_733.npy',
#  'clf_grid_june24pm.pkl_734.npy',
#  'clf_grid_june24pm.pkl_735.npy',
#  'clf_grid_june24pm.pkl_736.npy',
#  'clf_grid_june24pm.pkl_737.npy',
#  'clf_grid_june24pm.pkl_738.npy',
#  'clf_grid_june24pm.pkl_739.npy',
#  'clf_grid_june24pm.pkl_740.npy',
#  'clf_grid_june24pm.pkl_741.npy',
#  'clf_grid_june24pm.pkl_742.npy',
#  'clf_grid_june24pm.pkl_743.npy',
#  'clf_grid_june24pm.pkl_744.npy',
#  'clf_grid_june24pm.pkl_745.npy',
#  'clf_grid_june24pm.pkl_746.npy',
#  'clf_grid_june24pm.pkl_747.npy',
#  'clf_grid_june24pm.pkl_748.npy',
#  'clf_grid_june24pm.pkl_749.npy',
#  'clf_grid_june24pm.pkl_750.npy',
#  'clf_grid_june24pm.pkl_751.npy',
#  'clf_grid_june24pm.pkl_752.npy',
#  'clf_grid_june24pm.pkl_753.npy',
#  'clf_grid_june24pm.pkl_754.npy',
#  'clf_grid_june24pm.pkl_755.npy',
#  'clf_grid_june24pm.pkl_756.npy',
#  'clf_grid_june24pm.pkl_757.npy',
#  'clf_grid_june24pm.pkl_758.npy',
#  'clf_grid_june24pm.pkl_759.npy',
#  'clf_grid_june24pm.pkl_760.npy',
#  'clf_grid_june24pm.pkl_761.npy',
#  'clf_grid_june24pm.pkl_762.npy',
#  'clf_grid_june24pm.pkl_763.npy',
#  'clf_grid_june24pm.pkl_764.npy',
#  'clf_grid_june24pm.pkl_765.npy',
#  'clf_grid_june24pm.pkl_766.npy',
#  'clf_grid_june24pm.pkl_767.npy',
#  'clf_grid_june24pm.pkl_768.npy',
#  'clf_grid_june24pm.pkl_769.npy',
#  'clf_grid_june24pm.pkl_770.npy',
#  'clf_grid_june24pm.pkl_771.npy',
#  'clf_grid_june24pm.pkl_772.npy',
#  'clf_grid_june24pm.pkl_773.npy',
#  'clf_grid_june24pm.pkl_774.npy',
#  'clf_grid_june24pm.pkl_775.npy',
#  'clf_grid_june24pm.pkl_776.npy',
#  'clf_grid_june24pm.pkl_777.npy',
#  'clf_grid_june24pm.pkl_778.npy',
#  'clf_grid_june24pm.pkl_779.npy',
#  'clf_grid_june24pm.pkl_780.npy',
#  'clf_grid_june24pm.pkl_781.npy',
#  'clf_grid_june24pm.pkl_782.npy',
#  'clf_grid_june24pm.pkl_783.npy',
#  'clf_grid_june24pm.pkl_784.npy',
#  'clf_grid_june24pm.pkl_785.npy',
#  'clf_grid_june24pm.pkl_786.npy',
#  'clf_grid_june24pm.pkl_787.npy',
#  'clf_grid_june24pm.pkl_788.npy',
#  'clf_grid_june24pm.pkl_789.npy',
#  'clf_grid_june24pm.pkl_790.npy',
#  'clf_grid_june24pm.pkl_791.npy',
#  'clf_grid_june24pm.pkl_792.npy',
#  'clf_grid_june24pm.pkl_793.npy',
#  'clf_grid_june24pm.pkl_794.npy',
#  'clf_grid_june24pm.pkl_795.npy',
#  'clf_grid_june24pm.pkl_796.npy',
#  'clf_grid_june24pm.pkl_797.npy',
#  'clf_grid_june24pm.pkl_798.npy',
#  'clf_grid_june24pm.pkl_799.npy',
#  'clf_grid_june24pm.pkl_800.npy',
#  'clf_grid_june24pm.pkl_801.npy',
#  'clf_grid_june24pm.pkl_802.npy',
#  'clf_grid_june24pm.pkl_803.npy',
#  'clf_grid_june24pm.pkl_804.npy',
#  'clf_grid_june24pm.pkl_805.npy',
#  'clf_grid_june24pm.pkl_806.npy',
#  'clf_grid_june24pm.pkl_807.npy',
#  'clf_grid_june24pm.pkl_808.npy',
#  'clf_grid_june24pm.pkl_809.npy',
#  'clf_grid_june24pm.pkl_810.npy',
#  'clf_grid_june24pm.pkl_811.npy',
#  'clf_grid_june24pm.pkl_812.npy',
#  'clf_grid_june24pm.pkl_813.npy',
#  'clf_grid_june24pm.pkl_814.npy',
#  'clf_grid_june24pm.pkl_815.npy',
#  'clf_grid_june24pm.pkl_816.npy',
#  'clf_grid_june24pm.pkl_817.npy',
#  'clf_grid_june24pm.pkl_818.npy',
#  'clf_grid_june24pm.pkl_819.npy',
#  'clf_grid_june24pm.pkl_820.npy',
#  'clf_grid_june24pm.pkl_821.npy',
#  'clf_grid_june24pm.pkl_822.npy',
#  'clf_grid_june24pm.pkl_823.npy',
#  'clf_grid_june24pm.pkl_824.npy',
#  'clf_grid_june24pm.pkl_825.npy',
#  'clf_grid_june24pm.pkl_826.npy',
#  'clf_grid_june24pm.pkl_827.npy',
#  'clf_grid_june24pm.pkl_828.npy',
#  'clf_grid_june24pm.pkl_829.npy',
#  'clf_grid_june24pm.pkl_830.npy',
#  'clf_grid_june24pm.pkl_831.npy',
#  'clf_grid_june24pm.pkl_832.npy',
#  'clf_grid_june24pm.pkl_833.npy',
#  'clf_grid_june24pm.pkl_834.npy',
#  'clf_grid_june24pm.pkl_835.npy',
#  'clf_grid_june24pm.pkl_836.npy',
#  'clf_grid_june24pm.pkl_837.npy',
#  'clf_grid_june24pm.pkl_838.npy',
#  'clf_grid_june24pm.pkl_839.npy',
#  'clf_grid_june24pm.pkl_840.npy',
#  'clf_grid_june24pm.pkl_841.npy',
#  'clf_grid_june24pm.pkl_842.npy',
#  'clf_grid_june24pm.pkl_843.npy',
#  'clf_grid_june24pm.pkl_844.npy',
#  'clf_grid_june24pm.pkl_845.npy',
#  'clf_grid_june24pm.pkl_846.npy',
#  'clf_grid_june24pm.pkl_847.npy',
#  'clf_grid_june24pm.pkl_848.npy',
#  'clf_grid_june24pm.pkl_849.npy',
#  'clf_grid_june24pm.pkl_850.npy',
#  'clf_grid_june24pm.pkl_851.npy',
#  'clf_grid_june24pm.pkl_852.npy',
#  'clf_grid_june24pm.pkl_853.npy',
#  'clf_grid_june24pm.pkl_854.npy',
#  'clf_grid_june24pm.pkl_855.npy',
#  'clf_grid_june24pm.pkl_856.npy',
#  'clf_grid_june24pm.pkl_857.npy',
#  'clf_grid_june24pm.pkl_858.npy',
#  'clf_grid_june24pm.pkl_859.npy',
#  'clf_grid_june24pm.pkl_860.npy',
#  'clf_grid_june24pm.pkl_861.npy',
#  'clf_grid_june24pm.pkl_862.npy',
#  'clf_grid_june24pm.pkl_863.npy',
#  'clf_grid_june24pm.pkl_864.npy',
#  'clf_grid_june24pm.pkl_865.npy',
#  'clf_grid_june24pm.pkl_866.npy',
#  'clf_grid_june24pm.pkl_867.npy',
#  'clf_grid_june24pm.pkl_868.npy',
#  'clf_grid_june24pm.pkl_869.npy',
#  'clf_grid_june24pm.pkl_870.npy',
#  'clf_grid_june24pm.pkl_871.npy',
#  'clf_grid_june24pm.pkl_872.npy',
#  'clf_grid_june24pm.pkl_873.npy',
#  'clf_grid_june24pm.pkl_874.npy',
#  'clf_grid_june24pm.pkl_875.npy',
#  'clf_grid_june24pm.pkl_876.npy',
#  'clf_grid_june24pm.pkl_877.npy',
#  'clf_grid_june24pm.pkl_878.npy',
#  'clf_grid_june24pm.pkl_879.npy',
#  'clf_grid_june24pm.pkl_880.npy',
#  'clf_grid_june24pm.pkl_881.npy',
#  'clf_grid_june24pm.pkl_882.npy',
#  'clf_grid_june24pm.pkl_883.npy',
#  'clf_grid_june24pm.pkl_884.npy',
#  'clf_grid_june24pm.pkl_885.npy',
#  'clf_grid_june24pm.pkl_886.npy',
#  'clf_grid_june24pm.pkl_887.npy',
#  'clf_grid_june24pm.pkl_888.npy',
#  'clf_grid_june24pm.pkl_889.npy',
#  'clf_grid_june24pm.pkl_890.npy',
#  'clf_grid_june24pm.pkl_891.npy',
#  'clf_grid_june24pm.pkl_892.npy',
#  'clf_grid_june24pm.pkl_893.npy',
#  'clf_grid_june24pm.pkl_894.npy',
#  'clf_grid_june24pm.pkl_895.npy',
#  'clf_grid_june24pm.pkl_896.npy',
#  'clf_grid_june24pm.pkl_897.npy',
#  'clf_grid_june24pm.pkl_898.npy',
#  'clf_grid_june24pm.pkl_899.npy',
#  'clf_grid_june24pm.pkl_900.npy',
#  'clf_grid_june24pm.pkl_901.npy',
#  'clf_grid_june24pm.pkl_902.npy',
#  'clf_grid_june24pm.pkl_903.npy',
#  'clf_grid_june24pm.pkl_904.npy',
#  'clf_grid_june24pm.pkl_905.npy',
#  'clf_grid_june24pm.pkl_906.npy',
#  'clf_grid_june24pm.pkl_907.npy',
#  'clf_grid_june24pm.pkl_908.npy',
#  'clf_grid_june24pm.pkl_909.npy',
#  'clf_grid_june24pm.pkl_910.npy',
#  'clf_grid_june24pm.pkl_911.npy',
#  'clf_grid_june24pm.pkl_912.npy',
#  'clf_grid_june24pm.pkl_913.npy',
#  'clf_grid_june24pm.pkl_914.npy',
#  'clf_grid_june24pm.pkl_915.npy',
#  'clf_grid_june24pm.pkl_916.npy',
#  'clf_grid_june24pm.pkl_917.npy',
#  'clf_grid_june24pm.pkl_918.npy',
#  'clf_grid_june24pm.pkl_919.npy',
#  'clf_grid_june24pm.pkl_920.npy',
#  'clf_grid_june24pm.pkl_921.npy',
#  'clf_grid_june24pm.pkl_922.npy',
#  'clf_grid_june24pm.pkl_923.npy',
#  'clf_grid_june24pm.pkl_924.npy',
#  'clf_grid_june24pm.pkl_925.npy',
#  'clf_grid_june24pm.pkl_926.npy',
#  'clf_grid_june24pm.pkl_927.npy',
#  'clf_grid_june24pm.pkl_928.npy',
#  'clf_grid_june24pm.pkl_929.npy',
#  'clf_grid_june24pm.pkl_930.npy',
#  'clf_grid_june24pm.pkl_931.npy',
#  'clf_grid_june24pm.pkl_932.npy',
#  'clf_grid_june24pm.pkl_933.npy',
#  'clf_grid_june24pm.pkl_934.npy',
#  'clf_grid_june24pm.pkl_935.npy',
#  'clf_grid_june24pm.pkl_936.npy',
#  'clf_grid_june24pm.pkl_937.npy',
#  'clf_grid_june24pm.pkl_938.npy',
#  'clf_grid_june24pm.pkl_939.npy',
#  'clf_grid_june24pm.pkl_940.npy',
#  'clf_grid_june24pm.pkl_941.npy',
#  'clf_grid_june24pm.pkl_942.npy',
#  'clf_grid_june24pm.pkl_943.npy',
#  'clf_grid_june24pm.pkl_944.npy',
#  'clf_grid_june24pm.pkl_945.npy',
#  'clf_grid_june24pm.pkl_946.npy',
#  'clf_grid_june24pm.pkl_947.npy',
#  'clf_grid_june24pm.pkl_948.npy',
#  'clf_grid_june24pm.pkl_949.npy',
#  'clf_grid_june24pm.pkl_950.npy',
#  'clf_grid_june24pm.pkl_951.npy',
#  'clf_grid_june24pm.pkl_952.npy',
#  'clf_grid_june24pm.pkl_953.npy',
#  'clf_grid_june24pm.pkl_954.npy',
#  'clf_grid_june24pm.pkl_955.npy',
#  'clf_grid_june24pm.pkl_956.npy',
#  'clf_grid_june24pm.pkl_957.npy',
#  'clf_grid_june24pm.pkl_958.npy',
#  'clf_grid_june24pm.pkl_959.npy',
#  'clf_grid_june24pm.pkl_960.npy',
#  'clf_grid_june24pm.pkl_961.npy',
#  'clf_grid_june24pm.pkl_962.npy',
#  'clf_grid_june24pm.pkl_963.npy',
#  'clf_grid_june24pm.pkl_964.npy',
#  'clf_grid_june24pm.pkl_965.npy',
#  'clf_grid_june24pm.pkl_966.npy',
#  'clf_grid_june24pm.pkl_967.npy',
#  'clf_grid_june24pm.pkl_968.npy',
#  'clf_grid_june24pm.pkl_969.npy',
#  'clf_grid_june24pm.pkl_970.npy',
#  'clf_grid_june24pm.pkl_971.npy',
#  'clf_grid_june24pm.pkl_972.npy',
#  'clf_grid_june24pm.pkl_973.npy',
#  'clf_grid_june24pm.pkl_974.npy',
#  'clf_grid_june24pm.pkl_975.npy',
#  'clf_grid_june24pm.pkl_976.npy',
#  'clf_grid_june24pm.pkl_977.npy',
#  'clf_grid_june24pm.pkl_978.npy',
#  'clf_grid_june24pm.pkl_979.npy',
#  'clf_grid_june24pm.pkl_980.npy',
#  'clf_grid_june24pm.pkl_981.npy',
#  'clf_grid_june24pm.pkl_982.npy',
#  'clf_grid_june24pm.pkl_983.npy',
#  'clf_grid_june24pm.pkl_984.npy',
#  'clf_grid_june24pm.pkl_985.npy',
#  'clf_grid_june24pm.pkl_986.npy',
#  'clf_grid_june24pm.pkl_987.npy',
#  'clf_grid_june24pm.pkl_988.npy',
#  'clf_grid_june24pm.pkl_989.npy',
#  'clf_grid_june24pm.pkl_990.npy',
#  'clf_grid_june24pm.pkl_991.npy',
#  'clf_grid_june24pm.pkl_992.npy',
#  'clf_grid_june24pm.pkl_993.npy',
#  'clf_grid_june24pm.pkl_994.npy',
#  'clf_grid_june24pm.pkl_995.npy',
#  'clf_grid_june24pm.pkl_996.npy',
#  'clf_grid_june24pm.pkl_997.npy',
#  'clf_grid_june24pm.pkl_998.npy',
#  'clf_grid_june24pm.pkl_999.npy',
#  ...]
