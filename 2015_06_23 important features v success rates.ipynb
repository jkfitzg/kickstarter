# %%
# for top 5 features, plot distributions of each and probability of sucesss
# overall and within category
# move to .py

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
from IPython.display import display
from IPython.core.pylabtools import getfigs
import sklearn.metrics
import seaborn as sns
import pickle

# %%
# %matplotlib qt

# %%
from IPython.display import display
from IPython.core.pylabtools import getfigs

# %%
saveas_path = '/Users/jamie/insight data/figures/'

# %%
X_df = pd.read_pickle('X_df.save')

# %%
outcomes_df = pd.read_pickle('outcomes_df.save')

# %%
n_samples = np.shape(outcomes_df)[0]
print n_samples
# Out:
# 133071

# %%
rankings_order = [u'N_creator_backed', u'Goal', u'N_rewards', u'Body_n_words', u'N_links',
       u'Max_reward', u'Campaign_days', u'Median_reward', u'Reward_ship_days',
       u'Min_reward', u'N_figs', u'Month', u'Hour', u'Blurb_n_words',
       u'Monday_day', u'Title_n_words', u'Ships_intn', u'Week_day']

# %%
from plot_suggestions import *
# %load_ext autoreload
# %autoreload 2

# %%
plot_probability_funding_freq(X_df,outcomes_df,\
    'N_creator_backed',range(0,12),step=1,vline_x=0)
#display(plt.gcf())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d9f395826300> in <module>()
# ----> 1 plot_probability_funding_freq(X_df,outcomes_df,    'N_creator_backed',range(0,12),step=1,vline_x=0,if_log=True)
#       2 #display(plt.gcf())
#
# NameError: name 'X_df' is not defined

# %%
plt.close('all')

# %%
plot_probability_funding_freq(X_df,outcomes_df,\
                              'Goal',range(0,100001,2000),step=2000)
display(plt.gcf())
plt.close('all')

# %%
plot_probability_funding_freq(X_df,outcomes_df,'N_rewards',range(0,17))
display(plt.gcf())
plt.close('all')

# %%
plot_probability_funding_freq(X_df,outcomes_df,'Body_n_words',range(0,2000,50),100)
display(plt.gcf())
plt.close('all')

# %%
plot_probability_funding_freq(X_df,outcomes_df,'N_links',range(0,12))
display(plt.gcf())
plt.close('all')

# %%
plt.close('all')

# %%
plot_probability_funding_freq(X_df,outcomes_df,'Max_reward',range(0,1000,100),100)
display(plt.gcf())
plt.close('all')

# %%
plot_probability_funding_freq(X_df,outcomes_df,'Campaign_days',range(0,62,1))
display(plt.gcf())
plt.close('all')

# %%
plot_probability_funding_freq(X_df,outcomes_df,'Reward_ship_days',range(0,501,30))
display(plt.gcf())
plt.close('all')

# %%
plot_probability_funding_freq(X_df,outcomes_df,'Ships_intn',range(0,3,1))
display(plt.gcf())
plt.close('all')

# %%
np.array(X_df.columns)
# Out:
# array(['Goal', 'Campaign_days', 'Title_n_words', 'Blurb_n_words', 'Hour',
#        'N_rewards', 'Min_reward', 'Median_reward', 'Max_reward',
#        'Reward_ship_days', 'N_links', 'N_figs', 'Body_n_words',
#        'N_creator_backed', 'art', 'comics', 'crafts', 'dance', 'design',
#        'fashion', 'film', 'food', 'games', 'journalism', 'music',
#        'photography', 'publishing', 'technology', 'theater', 'Ships_intn',
#        'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec', 'Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat',
#        'Sun', '1d', '2d', '3d', '4d', '5d', '6d', '7d', '8d', '9d', '10d',
#        '11d', '12d', '13d', '14d', '15d', '16d', '17d', '18d', '19d',
#        '20d', '21d', '22d', '23d', '24d', '25d', '26d', '27d', '28d',
#        '29d', '30d', '31d', '0h', '1h', '2h', '3h', '4h', '5h', '6h', '7h',
#        '8h', '9h', '10h', '11h', '12h', '13h', '14h', '15h', '16h', '17h',
# ...

# %%
plot_probability_funding_freq(X_df,outcomes_df,'Fri',range(0,3,1))
display(plt.gcf())
plt.close('all')

# %%
plt.close('all')

# %%
# looks nice. later extend to within categories.
